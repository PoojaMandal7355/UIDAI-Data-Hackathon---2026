# %% [markdown]
# # District Cleaning — Maharashtra
#
# This notebook standardizes **district names** for this state across:
# - Enrolment data
# - Demographic update data
# - Biometric update data
#
# **All data is saved back to the same cleaned files.**

# %%
import pandas as pd
from pathlib import Path

pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)

CLEAN_DIR = Path("../../data/processed/cleaned")

enrol_df = pd.read_csv(CLEAN_DIR / "enrolment_clean.csv")
demo_df  = pd.read_csv(CLEAN_DIR / "demographic_clean.csv")
bio_df   = pd.read_csv(CLEAN_DIR / "biometric_clean.csv")

for df in [enrol_df, demo_df, bio_df]:
    df["state"] = df["state"].astype(str).str.strip().str.title()
    df["district"] = df["district"].astype(str).str.strip().str.title()

print("✅ All datasets loaded and normalized (Title Case)")
# Out:
# ✅ All datasets loaded and normalized (Title Case)

# %%
STATE_NAME = "Maharashtra"

districts = sorted(
    set(
        enrol_df.loc[enrol_df["state"] == STATE_NAME, "district"].dropna()
        .tolist()
    )
)

print(f"State: {STATE_NAME}")
print(f"Number of unique districts: {len(districts)}")

pd.DataFrame(
    {"District Name": districts}
)
# Out:
# State: Maharashtra
# Number of unique districts: 40
#                 District Name
# 0                 Ahilyanagar
# 1                       Akola
# 2                    Amravati
# 3                        Beed
# 4                    Bhandara
# 5                         Bid
# 6                    Buldhana
# 7                  Chandrapur
# 8   Chhatrapati Sambhajinagar
# 9                   Dharashiv
# 10                      Dhule
# 11                 Gadchiroli
# 12                     Gondia
# 13                    Hingoli
# 14                    Jalgaon
# 15                      Jalna
# 16                   Kolhapur
# 17                      Latur
# 18                     Mumbai
# 19                Mumbai City
# 20            Mumbai Suburban
# 21                     Nagpur
# 22                     Nanded
# 23                  Nandurbar
# 24                     Nashik
# 25                    Palghar
# 26                   Parbhani
# 27                       Pune
# 28                     Raigad
# 29                    Raigarh
# 30                Raigarh(Mh)
# 31                  Ratnagiri
# 32                     Sangli
# 33                     Satara
# 34                 Sindhudurg
# 35                    Solapur
# 36                      Thane
# 37                     Wardha
# 38                     Washim
# 39                   Yavatmal

# %% [markdown]
# ## District Mapping
#
# Add mappings in **Title Case only**.
#
# Format:
# ```python
# DISTRICT_MAPPING = {
#     "Correct District": ["Wrong Name 1", "Wrong Name 2"],
# }
# ```

# %%
DISTRICT_MAPPING = {
    # "Correct District": ["Wrong Variant 1", "Wrong Variant 2"]
    "Ahilyanagar": ["Ahmadnagar","Ahmed Nagar","Ahmednagar"],
    "Chhatrapati Sambhajinagar": ["Aurangabad","Chatrapati Sambhaji Nagar"],
    "Buldhana": ["Buldana"],
    "Gondia": ["Gondiya","Gondiya *"],
    "Hingoli": ["Hingoli *"],
    "Nandurbar": ["Nandurbar *"],
    "Dharashiv": ["Osmanabad"],
    "Mumbai Suburban": ["Mumbai( Sub Urban )"],
    "Washim": ["Washim *"]
}

def apply_mapping(df, state, mapping, label):
    total = 0
    for correct, wrongs in mapping.items():
        mask = (
            (df["state"] == state) &
            (df["district"].isin(wrongs))
        )
        count = mask.sum()
        df.loc[mask, "district"] = correct
        total += count
        if count > 0:
            print(f"✔ {label} → {correct} : {count} rows fixed")
    return total

total_fixes = 0
total_fixes += apply_mapping(enrol_df, STATE_NAME, DISTRICT_MAPPING, "Enrolment")
total_fixes += apply_mapping(demo_df,  STATE_NAME, DISTRICT_MAPPING, "Demographic")
total_fixes += apply_mapping(bio_df,   STATE_NAME, DISTRICT_MAPPING, "Biometric")

print(f"✅ Total fixes in {STATE_NAME}: {total_fixes}")
# Out:
# ✔ Enrolment → Ahilyanagar : 3896 rows fixed
# ✔ Enrolment → Chhatrapati Sambhajinagar : 2249 rows fixed
# ✔ Enrolment → Buldhana : 606 rows fixed
# ✔ Enrolment → Gondia : 651 rows fixed
# ✔ Enrolment → Hingoli : 1 rows fixed
# ✔ Enrolment → Nandurbar : 112 rows fixed
# ✔ Enrolment → Dharashiv : 1125 rows fixed
# ✔ Enrolment → Mumbai Suburban : 332 rows fixed
# ✔ Enrolment → Washim : 26 rows fixed
# ✔ Demographic → Ahilyanagar : 7258 rows fixed
# ✔ Demographic → Chhatrapati Sambhajinagar : 2839 rows fixed
# ✔ Demographic → Buldhana : 1458 rows fixed
# ✔ Demographic → Gondia : 1315 rows fixed
# ✔ Demographic → Hingoli : 2 rows fixed
# ✔ Demographic → Nandurbar : 240 rows fixed
# ✔ Demographic → Dharashiv : 1722 rows fixed
# ✔ Demographic → Mumbai Suburban : 1302 rows fixed
# ✔ Demographic → Washim : 246 rows fixed
# ✔ Biometric → Ahilyanagar : 8363 rows fixed
# ✔ Biometric → Chhatrapati Sambhajinagar : 3315 rows fixed
# ✔ Biometric → Buldhana : 1800 rows fixed
# ✔ Biometric → Gondia : 1474 rows fixed
# ✔ Biometric → Hingoli : 7 rows fixed
# ✔ Biometric → Nandurbar : 469 rows fixed
# ✔ Biometric → Dharashiv : 2001 rows fixed
# ✔ Biometric → Mumbai Suburban : 1694 rows fixed
# ✔ Biometric → Washim : 355 rows fixed
# ✅ Total fixes in Maharashtra: 44858

# %%
enrol_df.to_csv(CLEAN_DIR / "enrolment_clean.csv", index=False)
demo_df.to_csv(CLEAN_DIR / "demographic_clean.csv", index=False)
bio_df.to_csv(CLEAN_DIR / "biometric_clean.csv", index=False)

print("💾 All cleaned files saved successfully (overwritten)")
# Out:
# 💾 All cleaned files saved successfully (overwritten)
